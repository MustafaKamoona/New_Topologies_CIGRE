# %%
import numpy as np
import sympy as sym
import json
from pydae.urisi.urisi_builder import urisi

# %%
grid = urisi('cigre_eu_lv_acdc_4w.hjson')
grid.uz_jacs = False
grid.construct('cigre_eu_lv_acdc_4w')
grid.compile_mkl('cigre_eu_lv_acdc_4w')
